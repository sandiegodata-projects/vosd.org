# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/damoncrockett/vosd.org/215-opendsd/approval_master_FULL.csv')
# Out:
# /home/damoncrockett/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1070: DtypeWarning: Columns (11,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
df[df.ProjectId == 349132]
# Out:
#         Unnamed: 0            APN ApplicationDate ApplicationExpiration  \
# 303870      351250  452-666-05-00      2014-01-06   2024-01-04 17:00:00
#
#        ApplicationExpired  ApplicationMonth  ApplicationYear  ApprovalId  \
# 303870              False                 1             2014     1221439
#
#           Description  DevelopmentId  DevelopmentTitle   IssueDate  \
# 303870  2830 04TH AV          209601  Devel Num 209601  2014-08-12
#
#         IssueMonth  IssueYear      IssuedBy   JobId   Latitude   Longitude  \
# 303870           8       2014  Black, Laura  688066  32.734992 -117.161518
#
#          PermitHolder  ProjectId
# 303870  Russell Lloyd     349132 ...
#
# [1 rows x 30 columns]

# %%
df[df.PermitHolder.str.contains('Sean Shannon', na=False)]
# Out:
#         Unnamed: 0            APN ApplicationDate ApplicationExpiration  \
# 259465      303186  350-442-13-00      2012-08-08   2013-08-08 17:00:00
# 281069      326612  350-442-13-00      2013-04-15   2014-04-15 17:00:00
# 281070      326613  350-442-13-00      2013-04-15   2014-04-15 17:00:00
# 281071      326614  350-442-13-00      2013-04-15   2014-04-15 17:00:00
#
#        ApplicationExpired  ApplicationMonth  ApplicationYear  ApprovalId  \
# 259465               True                 8             2012     1022200
# 281069               True                 4             2013     1118635
# 281070               True                 4             2013     1118640
# 281071               True                 4             2013     1118634
#
#           Description  DevelopmentId  DevelopmentTitle   IssueDate  \
# 259465  634 PEARL ST          188581  Devel Num 188581  2012-10-11
# 281069  634 PEARL ST          188581  Devel Num 188581  2013-06-19
# 281070  634 PEARL ST          188581  Devel Num 188581  2013-06-19
# 281071  634 PEARL ST          188581  Devel Num 188581  2013-06-19
#
#         IssueMonth  IssueYear        IssuedBy   JobId   Latitude   Longitude  \
# 259465          10       2012   Adams, Tamara  583755  32.839776 -117.276508
# 281069           6       2013  Saborio, David  635762  32.839776 -117.276508
# 281070           6       2013  Saborio, David  635762  32.839776 -117.276508
# 281071           6       2013  Saborio, David  635762  32.839776 -117.276508
#
#         PermitHolder  ProjectId
# 259465  Sean Shannon     291387 ...
# 281069  Sean Shannon     320219 ...
# 281070  Sean Shannon     320219 ...
# 281071  Sean Shannon     320219 ...
#
# [4 rows x 30 columns]

# %%
p = df[df.StreetAddress.str.contains('634 PEARL', na=False)]

# %%
p.to_csv('/home/damoncrockett/vosd.org/215-opendsd/pescador.csv')

# %%
c = pd.read_csv('/home/damoncrockett/vosd.org/215-opendsd/customers_complete.csv')

# %%
c[c.Name.str.contains('Lloyd Russell', na=False)]
# Out:
#         Unnamed: 0  CustomerId           FirmName           Name  ProjectId  \
# 38867        38867       11273                NaN  Lloyd Russell      40978
# 38871        38871       82269              Owner  Lloyd Russell      40978
# 38872        38872       82269              Owner  Lloyd Russell      40978
# 75103        75103       82269              Owner  Lloyd Russell      62195
# 75104        75104       82269              Owner  Lloyd Russell      62195
# 78096        78096       88127                NaN  Lloyd Russell      63761
# 185217      185217       82269              Owner  Lloyd Russell     110838
# 185218      185218       88127                NaN  Lloyd Russell     110838
# 224723      224723       82269              Owner  Lloyd Russell     127001
# 237241      237241       82269              Owner  Lloyd Russell     131944
# 237242      237242       88127                NaN  Lloyd Russell     131944
# 237243      237243       88127                NaN  Lloyd Russell     131944
# 248733      248733       88127                NaN  Lloyd Russell     136546
# 284758      284758       88127                NaN  Lloyd Russell     150600
# 314886      314886      188582  Lloyd Russell AIA  Lloyd Russell     161484
# 350591      350591      188582  Lloyd Russell AIA  Lloyd Russell     175996
# 372661      372661      188582  Lloyd Russell AIA  Lloyd Russell     189466
# 372662      372662      188582  Lloyd Russell AIA  Lloyd Russell     189466
# 729481      729481      188582  Lloyd Russell AIA  Lloyd Russell     349132
# 729482      729482      188582  Lloyd Russell AIA  Lloyd Russell     349132
# 809971      809971      188582  Lloyd Russell AIA  Lloyd Russell     379876
# 809972      809972      188582  Lloyd Russell AIA  Lloyd Russell     379876
# 809973      809973      188582  Lloyd Russell AIA  Lloyd Russell     379876
#
#                       Role
# 38867        Owner/Builder
# 38871            Architect
# 38872                Owner
# 75103     Point of Contact
# 75104                Owner
# 78096            Architect
# 185217    Point of Contact
# 185218    Point of Contact
# 224723    Point of Contact
# 237241    Point of Contact
# 237242           Architect
# 237243    Point of Contact
# 248733            Designer
# 284758    Point of Contact
# 314886           Architect
# 350591    Point of Contact
# 372661    Point of Contact
# 372662  Inspection Contact
# 729481               Agent
# 729482    Point of Contact
# 809971               Agent
# 809972           Applicant
# 809973               Owner
#
# [23 rows x 6 columns]

# %%
a = df[df.ProjectId == 349132]

# %%
a.to_csv('/home/damoncrockett/vosd.org/215-opendsd/russell.csv')
