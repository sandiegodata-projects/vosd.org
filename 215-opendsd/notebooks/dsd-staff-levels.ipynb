# %%
# %matplotlib inline
import pandas as pd
import sqlite3
import json
import dateutil.parser
import datetime
import os
import gzip
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import *

# %%
approvals = pd.read_csv('/home/damoncrockett/vosd.org/215-opendsd/approval_master_FULL.csv')
# Out:
# /home/damoncrockett/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1070: DtypeWarning: Columns (11,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
len(approvals.index)
# Out:
# 388645

# %%
tmp = approvals[['ApplicationYear','TimetoIssue']]
by_year = tmp.groupby('ApplicationYear')
tmp = by_year.agg(np.mean)
tmp['count'] = by_year.size()
tmp
# Out:
#                  TimetoIssue  count
# ApplicationYear
# 2003               82.720207  13833
# 2004               57.067631  37262
# 2005               72.105641  40257
# 2006               68.938507  37198
# 2007               67.016005  34755
# 2008               60.156337  31354
# 2009               56.167511  28424
# 2010               50.687692  28664
# 2011               37.893032  28439
# 2012               40.546242  32206
# 2013               45.277585  39299
# 2014               17.388568  36954
#
# [12 rows x 2 columns]

# %%
tmp.to_csv('/home/damoncrockett/vosd.org/215-opendsd/annual_count.csv')

# %%
tmp = approvals[approvals.category == 'Discretionary'][['ApplicationYear','TimetoIssue']]
by_year = tmp.groupby('ApplicationYear')
tmp = by_year.agg(np.mean)
tmp['count'] = by_year.size()
tmp
# Out:
#                  TimetoIssue  count
# ApplicationYear
# 2003             1054.238255    932
# 2004              562.288107    970
# 2005              472.853524   1328
# 2006              465.149593   1004
# 2007              620.639908    701
# 2008              655.239362    636
# 2009              610.649573    536
# 2010              497.458716    318
# 2011              437.383117    417
# 2012              356.736842    431
# 2013              264.778195    438
# 2014              136.580000    517
#
# [12 rows x 2 columns]

# %%
tmp.to_csv('/home/damoncrockett/vosd.org/215-opendsd/annual_count_d.csv')

# %%
tmp = approvals[approvals.category == 'Ministerial'][['ApplicationYear','TimetoIssue']]
by_year = tmp.groupby('ApplicationYear')
tmp = by_year.agg(np.mean)
tmp['count'] = by_year.size()
tmp
# Out:
#                  TimetoIssue  count
# ApplicationYear
# 2003               54.830314  12850
# 2004               45.217563  35945
# 2005               55.713111  38194
# 2006               57.361733  35538
# 2007               54.666893  33455
# 2008               48.559764  30172
# 2009               45.653786  27452
# 2010               45.186642  27939
# 2011               31.736594  27363
# 2012               35.150401  31178
# 2013               42.108385  38100
# 2014               16.628799  35472
#
# [12 rows x 2 columns]

# %%
tmp.to_csv('/home/damoncrockett/vosd.org/215-opendsd/annual_count_m.csv')

# %%
bau = approvals[approvals.Type == 'Building Permit']

# %%
len(bau.index)
# Out:
# 34847

# %%
len(bau.ProjectManager.value_counts())
# Out:
# 140

# %%
staff = []
for i in range(2004,2014):
    tmp = bau[bau.ApplicationYear == i]
    n = len(tmp.ProjectManager.value_counts())
    staff.append(n)

# %%
staff
# Out:
# [59, 50, 61, 50, 49, 49, 37, 35, 42, 47]

# %%
tmp = bau[(bau.ApplicationYear > 2003) & (bau.ApplicationYear < 2014)]
tmp = tmp[['ApplicationYear','TimetoIssue']]
by_year = tmp.groupby('ApplicationYear')
tmp = by_year.agg(np.median)
tmp['Count'] = by_year.size()
tmp
# Out:
#                  TimetoIssue  Count
# ApplicationYear
# 2004                      36   2967
# 2005                      35   2912
# 2006                      25   3423
# 2007                      26   3141
# 2008                      30   3003
# 2009                      28   2423
# 2010                      24   2658
# 2011                      30   2881
# 2012                      34   3498
# 2013                      46   3951
#
# [10 rows x 2 columns]

# %%
tmp['staff'] = staff

# %%
tmp
# Out:
#                  TimetoIssue  Count  staff
# ApplicationYear
# 2004                      36   2967     59
# 2005                      35   2912     50
# 2006                      25   3423     61
# 2007                      26   3141     50
# 2008                      30   3003     49
# 2009                      28   2423     49
# 2010                      24   2658     37
# 2011                      30   2881     35
# 2012                      34   3498     42
# 2013                      46   3951     47
#
# [10 rows x 3 columns]

# %%
tmp.to_csv('/home/damoncrockett/vosd.org/215-opendsd/bau_year_count_staff.csv')
