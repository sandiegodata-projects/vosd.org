# %%
# %matplotlib inline
import pandas as pd
import sqlite3
import json
import dateutil.parser
import datetime
import os
import gzip
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import *

# %%
df = pd.read_csv('/home/damoncrockett/vosd.org/215-opendsd/approval_master_UNCUT.csv')

# %%
df = df[df.category == 'Discretionary']

# %%
len(df.index)
# Out:
# 8230

# %%
pd.DataFrame(df.Type.value_counts())
# Out:
#                                    0
# Coastal Development Permit      1694
# Site Development Permit         1307
# Tentative Map                    830
# Conditional Use Permit           791
# Map Waiver                       722
# Neighborhood Use Permit          555
# Planned Development Permit       516
# Public Right of Way Dedication   307
# Neighborhood Developmnt Permit   286
# Easement Vacation                248
# Variance                         212
# Public Right of Way Vacation     187
# Vesting Tentative Map            150
# Rezone                           115
# Master Plan, Establish            78
# Land Use Plan                     69
# Extension of Time - Dev. Pmt      51
# Street Name Change                40
# Public R.O.W. Use Permit          29
# Emergency Coastal Dev Permit      12
# Amendment of Approved Map         12
# City Council Approval              6
# City Manager Approval              3
# Emergency Authorization-ESL        3
# ...

# %%
d = df[(df.Type == 'Community Plan Amendment') | (df.Type == 'Rezone')]

# %%
del d['Unnamed: 0']

# %%
d.to_csv('/home/damoncrockett/vosd.org/215-opendsd/CPA_Rezone.csv', encoding = 'utf-8')
