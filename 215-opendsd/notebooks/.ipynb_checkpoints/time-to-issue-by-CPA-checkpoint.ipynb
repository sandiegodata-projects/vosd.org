# %%
import pandas as pd

# %%
d = pd.read_csv('/Users/damoncrockett/vosd.org/215-opendsd/tables/approvals_CPA.csv')
# Out:
# /Library/Python/2.7/site-packages/pandas/io/parsers.py:1164: DtypeWarning: Columns (12,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
d = d[['Latitude','Longitude','Type','category','CPA','TimetoIssue']]

# %%
d.head()
# Out:
#     Latitude   Longitude                           Type       category  \
# 0  32.727100 -117.100900  Grading + Right of Way Permit           BOTH
# 1  32.792299 -117.241771     Coastal Development Permit  Discretionary
# 2  32.792299 -117.241771                  Tentative Map  Discretionary
# 3  32.792570 -117.241852     Coastal Development Permit  Discretionary
# 4  32.792570 -117.241852                  Tentative Map  Discretionary
#
#                      CPA  TimetoIssue
# 0  MID-CITY:CITY HEIGHTS          999
# 1          PACIFIC BEACH          287
# 2          PACIFIC BEACH          287
# 3          PACIFIC BEACH          287
# 4          PACIFIC BEACH          287

# %%
m = d[d.category=='Ministerial']

# %%
d = d[d.category=='Discretionary']

# %%
import numpy as np
tmp = d.groupby('CPA')
p = tmp.agg(np.median)
p['count'] = tmp.size()
p.to_csv('/Users/damoncrockett/vosd.org/215-opendsd/tables/tti_by_CPA.csv')

# %%
p
# Out:
#                                       Latitude   Longitude  TimetoIssue  count
# CPA
# BALBOA PARK                          32.728859 -117.140321        506.0     16
# BARRIO LOGAN                         32.698966 -117.146214        463.0     66
# BLACK MOUNTAIN RANCH                 33.009210 -117.132882        381.0     69
# CARMEL MOUNTAIN RANCH                32.976966 -117.076046        415.5     19
# CLAIREMONT MESA                      32.811721 -117.199617        473.0    163
# COLLEGE AREA                         32.771003 -117.072670        409.5    116
# DEL MAR MESA                         32.942129 -117.188644        804.0     83
# DOWNTOWN                             32.718317 -117.163345        231.0    218
# EAST ELLIOTT                         32.847524 -117.026071       2003.0     33
# ENCANTO NEIGHBORHOODS,SOUTHEASTERN   32.709932 -117.075191        541.0    209
# FAIRBANKS RANCH COUNTRY CLUB         32.980853 -117.225229        938.0      7
# ...
